# %%
# !pip install opencv-contrib-python==4.4.0.44
# !pip install -U scikit-learn
# !pip install joblib

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import argparse as ap
import cv2
import imutils 
import numpy as np
import os
import glob
import math
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
#from sklearn.externals import joblib
import joblib
from scipy.cluster.vq import *
from sklearn.preprocessing import StandardScaler

import time
from IPython.display import display, clear_output

# %% [markdown]
# # Train Model & Find Features

# %%
train_path = "Dataset/train/"
training_names = os.listdir(train_path)
print(training_names)
# Out:
# ['book', 'cup', 'box']

# %%
image_books = glob.glob(train_path+"book/*")
image_cups = glob.glob(train_path+"cup/*")
image_boxes = glob.glob(train_path+"box/*")
print("Total Book Observations:\t", len(image_books))
print("Total Cups Observations:\t", len(image_cups))
print("Total Boxes Observations:\t", len(image_boxes))
# Out:
# Total Book Observations:	 280
# Total Cups Observations:	 257
# Total Boxes Observations:	 265

# %%
# Get all the path to the images and save them in a list
# image_paths and the corresponding label in image_paths
image_paths_train = []
image_classes = []
class_id = 0
for training_name in training_names:
    dir = os.path.join(train_path, training_name)
    #print(dir)
    class_path = imutils.imlist(dir)
    #print(class_path)
    image_paths_train+=class_path
    #print(image_paths_train)
    image_classes+=[class_id]*len(class_path)
    #print(image_classes)
    class_id+=1

# %%
# Create feature extraction and keypoint detector objects
#mser = cv2.MSER_create()
#mser = cv2.FeatureDetector_create('MSER')
sift = cv2.xfeatures2d.SIFT_create()
#surf = cv2.xfeatures2d.SURF_create()
#fea_det = cv2.FeatureDetector_create("SIFT")
#des_ext = cv2.DescriptorExtractor_create("SIFT")

# List where all the descriptors are stored
des_list = []
i = 1
print("Extracting features")
#i=0
for image_path in image_paths_train:
    im = cv2.imread(image_path)
    im = cv2.resize(im,(256,256))
    #im.resize((512,512))
    #if(image_path.find("book") > 0):
    im = cv2.GaussianBlur(im, (3,3), 20)
    #plt.imshow(im_original)
    #plt.show()
    #plt.imshow(im)
    #plt.show()
    #im = cv2.imread(image_path,cv2.IMREAD_GRAYSCALE)
    kpts, des = sift.detectAndCompute(im, None)
    #kpts, des = sift.detectAndCompute(im, None)
    #kpts = fea_det.detect(im)
    #kpts, des = des_ext.compute(im, kpts)
    des_list.append((image_path, des))  
    #imK = im.copy()
    #imK = cv2.drawKeypoints(im,kpts, imK) 
    #print(image_path)
    #plt.imshow(imK)
    #plt.show()
    clear_output(wait=True)
    display('Image '+str(i)+' over : '+str(len(image_paths_train)))
    #time.sleep(1)
    i += 1
    #i+=1
    #if(i>3):
    #    break
    
joblib.dump((des_list), "descriptors.pkl", compress=3)
# Out:
# 'Image 802 over : 802'
# ['descriptors.pkl']

# %%
des_list = joblib.load("descriptors.pkl")
# Stack all the descriptors vertically in a numpy array
descriptors = des_list[0][1]
image_classes = []
i = 0
for image_path, descriptor in des_list[1:]:
    try:
        descriptors = np.vstack((descriptors, descriptor))

        if(image_path.find("/book/") > 0):
            image_classes.append(0) # book - 0
        elif(image_path.find("/box/") > 0):
            image_classes.append(2) # box - 2
        else:
            image_classes.append(1) # cup - 1

    except ValueError:
        #print(image_path)
        i+=1
        continue
print("outlier %s on %s"%(i,np.shape(des_list)[0]))
#print(descriptors)

image_classes = np.asarray(image_classes)
print(image_classes.shape)
#print(image_classes)
# Out:
# outlier 0 on 802
# (801,)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
# Perform k-means clustering
print("k-means clustering")
k = 200
voc, variance = kmeans(descriptors, k, 50, 0.001)
# Out:
# k-means clustering

# %%
# Calculate the histogram of features
print("Calculate histogram of features")
im_features = np.zeros((len(image_classes), k), "float32")
for i in range(len(image_classes)):
    try:
        words, distance = vq(des_list[i][1],voc)
        for w in words:
            im_features[i][w] += 1
    except ValueError:
        continue
    

# Perform Tf-Idf vectorization
nbr_occurences = np.sum( (im_features > 0) * 1, axis = 0)
idf = np.array(np.log((1.0*len(image_classes)+1) / (1.0*nbr_occurences + 1)), 'float32')

# Scaling the words
stdSlr = StandardScaler().fit(im_features)
im_features = stdSlr.transform(im_features)
print(np.shape(des_list))
print(im_features.shape)
#print(np.array(image_classes))
# Out:
# Calculate histogram of features
# (802, 2)
# (801, 200)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
# Train the Linear SVM
print("Train SVM")
#svc = SVC()
#clf = GridSearchCV(svc, param_grid)
#clf = LinearSVC(tol=1e-10,max_iter=1e6)
#clf = LinearSVC()
#clf = SVC( C=6, kernel='rbf', gamma='scale', shrinking=True, tol=1e-6, cache_size=200, decision_function_shape='ovr') # -------- test set 4
#clf = SVC( C=1000, kernel='linear', tol=1e-6, cache_size=200, decision_function_shape='ovr')

clf = SVC( C=3, kernel='rbf', gamma='scale', shrinking=True, tol=1e-6, cache_size=200, decision_function_shape='ovr') # -------- test set occluded

clf.fit(im_features, np.array(image_classes))
#clf.fit(train_features, np.array(image_classes))
#sorted(clf.cv_results_.keys())
# Save the SVM
print("Save SVM")
joblib.dump((clf, training_names, stdSlr, k, voc, im_features), "bof.pkl", compress=3)
# save olso in picke format 
import pickle
save=open('bof_p.pkl', 'wb')
obj = pickle.dump((clf, training_names, stdSlr, k, voc, im_features),save,3)
# Out:
# Train SVM
# Save SVM
# ['bof.pkl']

# %% [markdown]
# # Test Model

# %%
# Load the classifier, class names, scaler, number of clusters and vocabulary 
clf, classes_names, stdSlr, k, voc, train_features = joblib.load("bof.pkl")


# Get the path of the testing image(s) and store them in a list
image_paths = []
test_path = './Dataset/test_unoccluded/' 
try:
    testing_names = os.listdir(test_path)
except OSError:
    print("No such directory %s\nCheck if the file exists"%(test_path))
    exit()
for testing_name in testing_names:
    dir = os.path.join(test_path, testing_name)
    class_path = imutils.imlist(dir)
    image_paths+=class_path

# %%
# Create feature extraction and keypoint detector objects
sift = cv2.xfeatures2d.SIFT_create(200)
#fea_det = cv2.FeatureDetector_create("SIFT")
#des_ext = cv2.DescriptorExtractor_create("SIFT")

# List where all the descriptors are stored
des_list_test = []

for image_path in image_paths:
    im = cv2.imread(image_path)
    #im = cv2.resize(im,(256,256))
    #im = cv2.imread(image_path,cv2.IMREAD_GRAYSCALE)
    #im = cv2.GaussianBlur(im_original, (47,47), 1000)
    #im = cv2.GaussianBlur(im, (5,5), 10)
    #im = cv2.GaussianBlur(im, (3,3), 20)
    if (im == None).any():
        print("No such file %s\nCheck if the file exists"%(image_path))
        exit()
    #kpts = fea_det.detect(im)
    #kpts, des = des_ext.compute(im, kpts)
    kpts, des = sift.detectAndCompute(im,None)
    des_list_test.append((image_path, des))   
    
    #imK = im.copy()
    #imK = cv2.drawKeypoints(im,kpts, imK) 
    #print(image_path)
    #plt.imshow(imK)
    #plt.show()
    #print(des.shape)

print("Save test features")
joblib.dump((des_list_test), "des_list_test.pkl", compress=3)
# Out:
# Save test features
# ['des_list_test.pkl']

# %%
des_list_test = joblib.load("des_list_test.pkl")
# Stack all the descriptors vertically in a numpy array
descriptors = des_list_test[0][1]
for image_path, descriptor in des_list_test[0:]:
    descriptors = np.vstack((descriptors, descriptor)) 

# 
test_features = np.zeros((len(image_paths), k), "float32")
for i in range(len(image_paths)):
    words, distance = vq(des_list_test[i][1],voc)
    for w in words:
        test_features[i][w] += 1

# Perform Tf-Idf vectorization
nbr_occurences = np.sum( (test_features > 0) * 1, axis = 0)
idf = np.array(np.log((1.0*len(image_paths)+1) / (1.0*nbr_occurences + 1)), 'float32')

# Scale the features
test_features = stdSlr.transform(test_features)
print("Save test features")
joblib.dump((test_features), "test_feat.pkl", compress=3)
# Out:
# Save test features
# ['test_feat.pkl']

# %% [markdown]
# #### Prediction with SVM

# %%
# Perform the predictions
#print(clf.predict(test_features))
test_features = joblib.load("test_feat.pkl")
predictions =  [classes_names[i] for i in clf.predict(test_features)]
visulaize = True
res = {"book": 0,"box": 0,"cup": 0}
# Visualize the results, if "visualize" flag set to true by the user
if visulaize:
    for image_path, prediction in zip(image_paths, predictions):
        #image = cv2.imread(image_path)
        print("image: %s - label: %s"%(image_path, prediction))
        if(image_path.find(prediction) > 0):
            res[prediction]+=1
        #cv2.namedWindow("Image", cv2.WINDOW_NORMAL)
        #pt = (0, 3 * image.shape[0] // 4)
        #cv2.putText(image, prediction, pt ,cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 2, [0, 255, 0], 2)
        #cv2.imshow("Image", image)
        #cv2.waitKey(50)
print("Reuslts out of  %g test images"%(len(predictions)))
print(res)
ris = [res[k] for k in res]
print("Accuracy: %.3g"%(sum(ris)/len(predictions)))
#cv2.destroyAllWindows()
# Out:
# image: 5/book/left_occ_obj_000577.png - label: book
# image: 5/book/left_occ_obj_000576.png - label: book
# image: 5/book/left_occ_obj_000580.png - label: book
# image: 5/book/left_occ_obj_000578.png - label: book
# image: 5/book/left_occ_obj_000581.png - label: book
# image: 5/book/left_occ_obj_000579.png - label: book
# image: 5/book/left_occ_obj_000582.png - label: book
# image: 5/book/left_occ_obj_000585.png - label: book
# image: 5/book/left_occ_obj_000584.png - label: book
# image: 5/book/left_occ_obj_000583.png - label: book
# image: 5/book/left_occ_obj_000588.png - label: book
# image: 5/book/left_occ_obj_000586.png - label: book
# image: 5/book/left_occ_obj_000587.png - label: book
# image: 5/book/left_occ_obj_000589.png - label: book
# image: 5/book/left_occ_obj_000680.png - label: cup
# image: 5/book/left_occ_obj_000681.png - label: box
# image: 5/book/left_occ_obj_000679.png - label: box
# image: 5/book/left_occ_obj_000682.png - label: box
# image: 5/book/left_occ_obj_000684.png - label: box
# image: 5/book/left_occ_obj_000683.png - label: box
# image: 5/book/left_occ_obj_000686.png - label: box
# image: 5/book/left_occ_obj_000685.png - label: box
# image: 5/book/left_occ_obj_000690.png - label: book
# image: 5/book/left_occ_obj_000687.png - label: book
# image: 5/book/left_occ_obj_000689.png - label: book
# image: 5/book/left_occ_obj_000688.png - label: box
# image: 5/book/left_occ_obj_000691.png - label: box
# image: 5/book/left_occ_obj_000694.png - label: book
# image: 5/book/left_occ_obj_000693.png - label: book
# image: 5/book/left_occ_obj_000692.png - label: book
# image: 5/book/left_occ_obj_000696.png - label: book
# image: 5/book/left_occ_obj_000695.png - label: book
# image: 5/book/left_occ_obj_000697.png - label: book
# image: 5/book/left_occ_obj_000700.png - label: book
# image: 5/book/left_occ_obj_000699.png - label: book
# image: 5/book/left_occ_obj_000698.png - label: book
# image: 5/book/left_occ_obj_000701.png - label: book
# image: 5/book/left_occ_obj_000702.png - label: book
# image: 5/book/left_occ_obj_000703.png - label: book
# image: 5/book/left_occ_obj_000704.png - label: book
# image: 5/book/left_occ_obj_000705.png - label: book
# image: 5/book/left_occ_obj_000707.png - label: book
# image: 5/book/left_occ_obj_000706.png - label: book
# image: 5/book/left_occ_obj_001207.png - label: book
# image: 5/book/left_occ_obj_001206.png - label: book
# image: 5/book/left_occ_obj_001205.png - label: box
# image: 5/book/left_occ_obj_001209.png - label: book
# image: 5/book/left_occ_obj_001210.png - label: book
# image: 5/book/left_occ_obj_001211.png - label: box
# image: 5/book/left_occ_obj_001208.png - label: book
# image: 5/book/left_occ_obj_001214.png - label: box
# image: 5/book/left_occ_obj_001213.png - label: book
# image: 5/book/left_occ_obj_001212.png - label: book
# image: 5/book/left_occ_obj_001215.png - label: book
# image: 5/book/left_occ_obj_001216.png - label: book
# image: 5/book/left_occ_obj_001217.png - label: book
# image: 5/book/left_occ_obj_001218.png - label: box
# image: 5/book/left_occ_obj_001302.png - label: cup
# image: 5/book/left_occ_obj_001304.png - label: box
# image: 5/book/left_occ_obj_001303.png - label: cup
# image: 5/book/left_occ_obj_001306.png - label: book
# image: 5/book/left_occ_obj_001305.png - label: book
# image: 5/book/left_occ_obj_001307.png - label: book
# image: 5/book/left_occ_obj_001308.png - label: book
# image: 5/book/left_occ_obj_001312.png - label: book
# image: 5/book/left_occ_obj_001309.png - label: book
# image: 5/book/left_occ_obj_001310.png - label: book
# image: 5/book/left_occ_obj_001311.png - label: book
# image: 5/book/left_occ_obj_001313.png - label: book
# image: 5/book/left_occ_obj_001314.png - label: book
# image: 5/book/left_occ_obj_001316.png - label: book
# image: 5/book/left_occ_obj_001315.png - label: book
# image: 5/book/left_occ_obj_001317.png - label: book
# image: 5/book/left_occ_obj_001318.png - label: cup
# image: 5/book/left_occ_obj_001319.png - label: book
# image: 5/book/left_occ_obj_001323.png - label: book
# image: 5/book/left_occ_obj_001322.png - label: book
# image: 5/book/left_occ_obj_001320.png - label: book
# image: 5/book/left_occ_obj_001321.png - label: book
# image: 5/book/left_occ_obj_001324.png - label: book
# image: 5/book/left_occ_obj_001327.png - label: book
# image: 5/book/left_occ_obj_001325.png - label: book
# image: 5/book/left_occ_obj_001326.png - label: book
# image: 5/book/left_occ_obj_001330.png - label: book
# image: 5/book/left_occ_obj_001329.png - label: book
# image: 5/book/left_occ_obj_001331.png - label: book
# image: 5/book/left_occ_obj_001328.png - label: book
# image: 5/book/left_occ_obj_001333.png - label: book
# image: 5/book/left_occ_obj_001332.png - label: book
# image: 5/book/left_occ_obj_001334.png - label: book
# image: 5/book/left_occ_obj_001335.png - label: book
# image: 5/cup/left_occ_obj_000783.png - label: cup
# image: 5/cup/left_occ_obj_000785.png - label: box
# image: 5/cup/left_occ_obj_000784.png - label: cup
# image: 5/cup/left_occ_obj_000786.png - label: box
# image: 5/cup/left_occ_obj_000787.png - label: cup
# image: 5/cup/left_occ_obj_000789.png - label: cup
# image: 5/cup/left_occ_obj_000790.png - label: cup
# image: 5/cup/left_occ_obj_000788.png - label: cup
# image: 5/cup/left_occ_obj_000794.png - label: box
# image: 5/cup/left_occ_obj_000791.png - label: cup
# image: 5/cup/left_occ_obj_000793.png - label: cup
# image: 5/cup/left_occ_obj_000792.png - label: box
# image: 5/cup/left_occ_obj_000796.png - label: cup
# image: 5/cup/left_occ_obj_000795.png - label: cup
# image: 5/cup/left_occ_obj_000892.png - label: cup
# image: 5/cup/left_occ_obj_000893.png - label: cup
# image: 5/cup/left_occ_obj_000894.png - label: cup
# image: 5/cup/left_occ_obj_000895.png - label: cup
# image: 5/cup/left_occ_obj_000897.png - label: cup
# image: 5/cup/left_occ_obj_000899.png - label: cup
# image: 5/cup/left_occ_obj_000896.png - label: cup
# image: 5/cup/left_occ_obj_000898.png - label: cup
# image: 5/cup/left_occ_obj_000903.png - label: cup
# image: 5/cup/left_occ_obj_000901.png - label: cup
# image: 5/cup/left_occ_obj_000900.png - label: cup
# image: 5/cup/left_occ_obj_000902.png - label: cup
# image: 5/cup/left_occ_obj_000906.png - label: cup
# image: 5/cup/left_occ_obj_000905.png - label: cup
# image: 5/cup/left_occ_obj_000904.png - label: cup
# image: 5/cup/left_occ_obj_000907.png - label: cup
# image: 5/cup/left_occ_obj_000910.png - label: box
# image: 5/cup/left_occ_obj_000911.png - label: cup
# image: 5/cup/left_occ_obj_000909.png - label: cup
# image: 5/cup/left_occ_obj_000908.png - label: cup
# image: 5/cup/left_occ_obj_000912.png - label: box
# image: 5/cup/left_occ_obj_000914.png - label: cup
# image: 5/cup/left_occ_obj_000913.png - label: cup
# image: 5/cup/left_occ_obj_000915.png - label: cup
# image: 5/cup/left_occ_obj_000917.png - label: box
# image: 5/cup/left_occ_obj_000918.png - label: cup
# image: 5/cup/left_occ_obj_000919.png - label: cup
# image: 5/cup/left_occ_obj_000916.png - label: cup
# image: 5/cup/left_occ_obj_000920.png - label: box
# image: 5/cup/left_occ_obj_000921.png - label: cup
# image: 5/cup/left_occ_obj_000923.png - label: cup
# image: 5/cup/left_occ_obj_000922.png - label: cup
# image: 5/cup/left_occ_obj_000924.png - label: cup
# image: 5/cup/left_occ_obj_000925.png - label: cup
# image: 5/cup/left_occ_obj_000993.png - label: cup
# image: 5/cup/left_occ_obj_000994.png - label: cup
# image: 5/cup/left_occ_obj_000996.png - label: cup
# image: 5/cup/left_occ_obj_000995.png - label: cup
# image: 5/cup/left_occ_obj_000998.png - label: cup
# image: 5/cup/left_occ_obj_000997.png - label: cup
# image: 5/cup/left_occ_obj_001002.png - label: cup
# image: 5/cup/left_occ_obj_000999.png - label: box
# image: 5/cup/left_occ_obj_001000.png - label: cup
# image: 5/cup/left_occ_obj_001001.png - label: cup
# image: 5/cup/left_occ_obj_001007.png - label: cup
# image: 5/cup/left_occ_obj_001003.png - label: cup
# image: 5/cup/left_occ_obj_001006.png - label: box
# image: 5/cup/left_occ_obj_001005.png - label: box
# image: 5/cup/left_occ_obj_001004.png - label: box
# image: 5/cup/left_occ_obj_001008.png - label: cup
# image: 5/cup/left_occ_obj_001011.png - label: cup
# image: 5/cup/left_occ_obj_001010.png - label: cup
# image: 5/cup/left_occ_obj_001009.png - label: box
# image: 5/cup/left_occ_obj_001012.png - label: cup
# image: 5/cup/left_occ_obj_001096.png - label: cup
# image: 5/cup/left_occ_obj_001095.png - label: box
# image: 5/cup/left_occ_obj_001097.png - label: box
# image: 5/cup/left_occ_obj_001098.png - label: box
# image: 5/cup/left_occ_obj_001100.png - label: box
# image: 5/cup/left_occ_obj_001099.png - label: box
# image: 5/cup/left_occ_obj_001101.png - label: box
# image: 5/cup/left_occ_obj_001105.png - label: box
# image: 5/cup/left_occ_obj_001102.png - label: cup
# image: 5/cup/left_occ_obj_001104.png - label: box
# image: 5/cup/left_occ_obj_001103.png - label: box
# image: 5/cup/left_occ_obj_001109.png - label: cup
# image: 5/cup/left_occ_obj_001108.png - label: cup
# image: 5/cup/left_occ_obj_001107.png - label: cup
# image: 5/cup/left_occ_obj_001106.png - label: cup
# image: 5/cup/left_occ_obj_001110.png - label: cup
# image: 5/cup/left_occ_obj_001112.png - label: box
# image: 5/cup/left_occ_obj_001111.png - label: cup
# image: 5/cup/left_occ_obj_001113.png - label: box
# image: 5/cup/left_occ_obj_001116.png - label: cup
# image: 5/cup/left_occ_obj_001114.png - label: box
# image: 5/cup/left_occ_obj_001115.png - label: box
# image: 5/cup/left_occ_obj_001120.png - label: box
# image: 5/cup/left_occ_obj_001119.png - label: box
# image: 5/cup/left_occ_obj_001117.png - label: cup
# image: 5/cup/left_occ_obj_001118.png - label: box
# image: 5/cup/left_occ_obj_001123.png - label: box
# image: 5/cup/left_occ_obj_001124.png - label: cup
# image: 5/cup/left_occ_obj_001122.png - label: box
# image: 5/cup/left_occ_obj_001121.png - label: cup
# image: 5/cup/left_occ_obj_001127.png - label: box
# image: 5/cup/left_occ_obj_001126.png - label: box
# image: 5/cup/left_occ_obj_001125.png - label: box
# image: 5/cup/left_occ_obj_001128.png - label: box
# image: 5/cup/left_occ_obj_001129.png - label: cup
# image: 5/cup/left_occ_obj_001131.png - label: box
# image: 5/cup/left_occ_obj_001130.png - label: box
# image: 5/box/left_occ_obj_000114.png - label: cup
# image: 5/box/left_occ_obj_000115.png - label: cup
# image: 5/box/left_occ_obj_000112.png - label: box
# image: 5/box/left_occ_obj_000113.png - label: box
# image: 5/box/left_occ_obj_000118.png - label: cup
# image: 5/box/left_occ_obj_000116.png - label: box
# image: 5/box/left_occ_obj_000117.png - label: box
# image: 5/box/left_occ_obj_000121.png - label: box
# image: 5/box/left_occ_obj_000120.png - label: box
# image: 5/box/left_occ_obj_000119.png - label: box
# image: 5/box/left_occ_obj_000122.png - label: box
# image: 5/box/left_occ_obj_000125.png - label: box
# image: 5/box/left_occ_obj_000123.png - label: box
# image: 5/box/left_occ_obj_000126.png - label: box
# image: 5/box/left_occ_obj_000124.png - label: cup
# image: 5/box/left_occ_obj_000227.png - label: box
# image: 5/box/left_occ_obj_000229.png - label: cup
# image: 5/box/left_occ_obj_000228.png - label: box
# image: 5/box/left_occ_obj_000226.png - label: box
# image: 5/box/left_occ_obj_000231.png - label: box
# image: 5/box/left_occ_obj_000230.png - label: box
# image: 5/box/left_occ_obj_000232.png - label: box
# image: 5/box/left_occ_obj_000233.png - label: box
# image: 5/box/left_occ_obj_000237.png - label: box
# image: 5/box/left_occ_obj_000234.png - label: box
# image: 5/box/left_occ_obj_000235.png - label: box
# image: 5/box/left_occ_obj_000236.png - label: box
# image: 5/box/left_occ_obj_000240.png - label: box
# image: 5/box/left_occ_obj_000241.png - label: box
# image: 5/box/left_occ_obj_000239.png - label: box
# image: 5/box/left_occ_obj_000238.png - label: box
# image: 5/box/left_occ_obj_000244.png - label: box
# image: 5/box/left_occ_obj_000242.png - label: box
# image: 5/box/left_occ_obj_000243.png - label: box
# image: 5/box/left_occ_obj_000245.png - label: box
# image: 5/box/left_occ_obj_000247.png - label: box
# image: 5/box/left_occ_obj_000249.png - label: box
# image: 5/box/left_occ_obj_000248.png - label: box
# image: 5/box/left_occ_obj_000246.png - label: box
# image: 5/box/left_occ_obj_000250.png - label: box
# image: 5/box/left_occ_obj_000251.png - label: box
# image: 5/box/left_occ_obj_000252.png - label: box
# image: 5/box/left_occ_obj_000253.png - label: box
# image: 5/box/left_occ_obj_000256.png - label: box
# image: 5/box/left_occ_obj_000254.png - label: box
# image: 5/box/left_occ_obj_000255.png - label: box
# image: 5/box/left_occ_obj_000257.png - label: box
# image: 5/box/left_occ_obj_000320.png - label: cup
# image: 5/box/left_occ_obj_000319.png - label: box
# image: 5/box/left_occ_obj_000318.png - label: box
# image: 5/box/left_occ_obj_000323.png - label: box
# image: 5/box/left_occ_obj_000321.png - label: box
# image: 5/box/left_occ_obj_000322.png - label: box
# image: 5/box/left_occ_obj_000427.png - label: box
# image: 5/box/left_occ_obj_000429.png - label: box
# image: 5/box/left_occ_obj_000426.png - label: cup
# image: 5/box/left_occ_obj_000428.png - label: box
# image: 5/box/left_occ_obj_000431.png - label: box
# image: 5/box/left_occ_obj_000432.png - label: box
# image: 5/box/left_occ_obj_000433.png - label: box
# image: 5/box/left_occ_obj_000430.png - label: box
# image: 5/box/left_occ_obj_000437.png - label: cup
# image: 5/box/left_occ_obj_000436.png - label: box
# image: 5/box/left_occ_obj_000434.png - label: box
# image: 5/box/left_occ_obj_000435.png - label: cup
# image: 5/box/left_occ_obj_000441.png - label: box
# image: 5/box/left_occ_obj_000438.png - label: cup
# image: 5/box/left_occ_obj_000439.png - label: box
# image: 5/box/left_occ_obj_000440.png - label: cup
# image: 5/box/left_occ_obj_000442.png - label: box
# image: 5/box/left_occ_obj_000444.png - label: box
# image: 5/box/left_occ_obj_000445.png - label: box
# image: 5/box/left_occ_obj_000443.png - label: cup
# image: 5/box/left_occ_obj_000447.png - label: cup
# image: 5/box/left_occ_obj_000448.png - label: cup
# image: 5/box/left_occ_obj_000446.png - label: box
# image: 5/box/left_occ_obj_000450.png - label: cup
# image: 5/box/left_occ_obj_000449.png - label: box
# image: 5/box/left_occ_obj_000451.png - label: cup
# image: 5/box/left_occ_obj_000452.png - label: box
# image: 5/box/left_occ_obj_000454.png - label: cup
# image: 5/box/left_occ_obj_000453.png - label: cup
# image: 5/box/left_occ_obj_000455.png - label: box
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 73, 'box': 65, 'cup': 68}
# Accuracy: 0.738

# %% [markdown]
# #### Nearest neighbour

# %%
predictions = [None]*(len(test_features))

for j,test in enumerate(test_features):
    min = 1e100
    for i, train in enumerate(train_features):
        val = math.sqrt(sum(pow(test-train,2)))
        if(val < min):
            min = val;
            #print(image_classes[i])
            #print(classes_names[0])
            predictions[j] = classes_names[image_classes[i]]
res = {"book": 0,"box": 0,"cup": 0}
# Visualize the results, if "visualize" flag set to true by the user
if visulaize:
    for image_path, prediction in zip(image_paths, predictions):
        #image = cv2.imread(image_path)
        print("image: %s - label: %s"%(image_path, prediction))
        if(image_path.find(prediction) > 0):
            res[prediction]+=1
        #cv2.namedWindow("Image", cv2.WINDOW_NORMAL)
        #pt = (0, 3 * image.shape[0] // 4)
        #cv2.putText(image, prediction, pt ,cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 2, [0, 255, 0], 2)
        #cv2.imshow("Image", image)
        #cv2.waitKey(50)
print("Reuslts out of  %g test images"%(len(predictions)))
print(res)
ris = [res[k] for k in res]
print("Accuracy: %.3g"%(sum(ris)/len(predictions)))
# Out:
# ['cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'box', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'box', 'book', 'cup', 'cup', 'cup', 'book', 'book', 'book', 'cup', 'book', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'book', 'box', 'cup', 'cup', 'box', 'cup', 'box', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'box', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'box', 'cup', 'cup', 'book', 'box', 'book', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'box', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'box', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'book', 'cup', 'box', 'box', 'cup', 'cup', 'box', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'cup', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'cup', 'box', 'box', 'box', 'box', 'box', 'box', 'cup', 'box', 'cup', 'box', 'box', 'box', 'box', 'cup', 'cup', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'cup', 'book', 'book', 'book', 'book', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'cup', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'cup', 'box', 'box', 'cup', 'box', 'book', 'box', 'cup', 'box', 'cup', 'book', 'box', 'box', 'box', 'box', 'box', 'cup', 'box', 'box', 'box', 'box', 'box', 'box', 'book', 'box', 'book', 'book', 'box', 'box', 'book', 'book', 'book', 'book', 'cup', 'box', 'box', 'box', 'book', 'box', 'box', 'box', 'book', 'box', 'book', 'box', 'box', 'book', 'book', 'book', 'book', 'box', 'book', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'cup', 'cup', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'box', 'cup', 'box', 'cup', 'box', 'cup', 'cup', 'box', 'box', 'box', 'box', 'cup', 'book', 'box', 'box', 'box', 'cup', 'box', 'box', 'box', 'box', 'box', 'book', 'book', 'book', 'book', 'box', 'book', 'book', 'book', 'box', 'cup', 'book', 'book', 'book', 'box', 'book', 'box', 'book', 'box', 'book', 'box', 'box', 'box', 'book', 'cup', 'book', 'box', 'box', 'cup', 'cup', 'box', 'book', 'box', 'box', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'cup', 'box', 'box', 'book', 'box', 'book', 'cup', 'box', 'book', 'box', 'book', 'book', 'box', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'cup', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'cup', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'box', 'book', 'book', 'box', 'book', 'book', 'box', 'box', 'book', 'box', 'book', 'book', 'box', 'cup', 'book', 'box', 'book', 'book', 'box', 'box', 'box', 'box', 'book', 'book', 'box', 'box', 'book', 'box', 'book', 'box', 'book', 'book', 'book',  ...
# image: 3/cup/right_obj_116.png - label: cup
# image: 3/cup/right_obj_114.png - label: cup
# image: 3/cup/right_obj_113.png - label: cup
# image: 3/cup/right_obj_110.png - label: cup
# image: 3/cup/right_obj_112.png - label: cup
# image: 3/cup/right_obj_109.png - label: cup
# image: 3/cup/right_obj_106.png - label: cup
# image: 3/cup/right_obj_105.png - label: cup
# image: 3/cup/right_obj_108.png - label: cup
# image: 3/cup/right_obj_104.png - label: cup
# image: 3/cup/right_obj_101.png - label: box
# image: 3/cup/right_obj_103.png - label: cup
# image: 3/cup/right_obj_157.png - label: cup
# image: 3/cup/right_obj_156.png - label: cup
# image: 3/cup/right_obj_153.png - label: cup
# image: 3/cup/right_obj_152.png - label: cup
# image: 3/cup/right_obj_151.png - label: cup
# image: 3/cup/right_obj_150.png - label: cup
# image: 3/cup/right_obj_149.png - label: box
# image: 3/cup/right_obj_146.png - label: book
# image: 3/cup/right_obj_145.png - label: cup
# image: 3/cup/right_obj_148.png - label: cup
# image: 3/cup/right_obj_143.png - label: cup
# image: 3/cup/right_obj_140.png - label: book
# image: 3/cup/right_obj_142.png - label: book
# image: 3/cup/right_obj_139.png - label: book
# image: 3/cup/right_obj_138.png - label: cup
# image: 3/cup/right_obj_137.png - label: book
# image: 3/cup/right_obj_136.png - label: cup
# image: 3/cup/right_obj_135.png - label: cup
# image: 3/cup/right_obj_131.png - label: cup
# image: 3/cup/right_obj_132.png - label: cup
# image: 3/cup/right_obj_130.png - label: cup
# image: 3/cup/right_obj_129.png - label: cup
# image: 3/cup/right_obj_127.png - label: cup
# image: 3/cup/right_obj_126.png - label: cup
# image: 3/cup/right_obj_124.png - label: book
# image: 3/cup/right_obj_125.png - label: box
# image: 3/cup/right_obj_123.png - label: cup
# image: 3/cup/right_obj_121.png - label: cup
# image: 3/cup/right_obj_118.png - label: box
# image: 3/cup/right_obj_119.png - label: cup
# image: 3/cup/right_obj_117.png - label: box
# image: 3/cup/right_obj_206.png - label: cup
# image: 3/cup/right_obj_205.png - label: cup
# image: 3/cup/right_obj_204.png - label: cup
# image: 3/cup/right_obj_203.png - label: cup
# image: 3/cup/right_obj_202.png - label: cup
# image: 3/cup/right_obj_198.png - label: cup
# image: 3/cup/right_obj_197.png - label: cup
# image: 3/cup/right_obj_201.png - label: cup
# image: 3/cup/right_obj_196.png - label: cup
# image: 3/cup/right_obj_195.png - label: cup
# image: 3/cup/right_obj_190.png - label: cup
# image: 3/cup/right_obj_192.png - label: cup
# image: 3/cup/right_obj_193.png - label: cup
# image: 3/cup/right_obj_191.png - label: cup
# image: 3/cup/right_obj_189.png - label: cup
# image: 3/cup/right_obj_184.png - label: cup
# image: 3/cup/right_obj_183.png - label: cup
# image: 3/cup/right_obj_187.png - label: cup
# image: 3/cup/right_obj_185.png - label: cup
# image: 3/cup/right_obj_182.png - label: cup
# image: 3/cup/right_obj_180.png - label: cup
# image: 3/cup/right_obj_179.png - label: cup
# image: 3/cup/right_obj_176.png - label: cup
# image: 3/cup/right_obj_178.png - label: cup
# image: 3/cup/right_obj_175.png - label: box
# image: 3/cup/right_obj_174.png - label: cup
# image: 3/cup/right_obj_172.png - label: cup
# image: 3/cup/right_obj_171.png - label: cup
# image: 3/cup/right_obj_170.png - label: cup
# image: 3/cup/right_obj_169.png - label: cup
# image: 3/cup/right_obj_167.png - label: cup
# image: 3/cup/right_obj_165.png - label: cup
# image: 3/cup/right_obj_164.png - label: box
# image: 3/cup/right_obj_163.png - label: cup
# image: 3/cup/right_obj_162.png - label: cup
# image: 3/cup/right_obj_159.png - label: book
# image: 3/cup/right_obj_161.png - label: box
# image: 3/cup/right_obj_158.png - label: book
# image: 3/cup/right_obj_335.png - label: cup
# image: 3/cup/right_obj_336.png - label: cup
# image: 3/cup/right_obj_337.png - label: cup
# image: 3/cup/right_obj_339.png - label: cup
# image: 3/cup/right_obj_333.png - label: cup
# image: 3/cup/right_obj_331.png - label: cup
# image: 3/cup/right_obj_330.png - label: cup
# image: 3/cup/right_obj_329.png - label: cup
# image: 3/cup/right_obj_328.png - label: cup
# image: 3/cup/right_obj_327.png - label: cup
# image: 3/cup/right_obj_324.png - label: cup
# image: 3/cup/right_obj_322.png - label: cup
# image: 3/cup/right_obj_326.png - label: cup
# image: 3/cup/right_obj_321.png - label: cup
# image: 3/cup/right_obj_320.png - label: cup
# image: 3/cup/right_obj_318.png - label: cup
# image: 3/cup/right_obj_317.png - label: cup
# image: 3/cup/right_obj_315.png - label: cup
# image: 3/cup/right_obj_316.png - label: cup
# image: 3/cup/right_obj_314.png - label: cup
# image: 3/cup/right_obj_308.png - label: cup
# image: 3/cup/right_obj_313.png - label: cup
# image: 3/cup/right_obj_310.png - label: cup
# image: 3/cup/right_obj_309.png - label: cup
# image: 3/cup/right_obj_307.png - label: cup
# image: 3/cup/right_obj_305.png - label: cup
# image: 3/cup/right_obj_304.png - label: cup
# image: 3/cup/right_obj_303.png - label: cup
# image: 3/cup/right_obj_302.png - label: cup
# image: 3/cup/right_obj_300.png - label: cup
# image: 3/cup/right_obj_297.png - label: cup
# image: 3/cup/right_obj_209.png - label: cup
# image: 3/cup/right_obj_299.png - label: box
# image: 3/cup/right_obj_208.png - label: cup
# image: 3/cup/right_obj_211.png - label: cup
# image: 3/cup/right_obj_381.png - label: cup
# image: 3/cup/right_obj_376.png - label: cup
# image: 3/cup/right_obj_379.png - label: cup
# image: 3/cup/right_obj_373.png - label: cup
# image: 3/cup/right_obj_374.png - label: cup
# image: 3/cup/right_obj_375.png - label: cup
# image: 3/cup/right_obj_371.png - label: cup
# image: 3/cup/right_obj_370.png - label: cup
# image: 3/cup/right_obj_369.png - label: cup
# image: 3/cup/right_obj_368.png - label: cup
# image: 3/cup/right_obj_366.png - label: cup
# image: 3/cup/right_obj_365.png - label: cup
# image: 3/cup/right_obj_360.png - label: cup
# image: 3/cup/right_obj_361.png - label: cup
# image: 3/cup/right_obj_362.png - label: cup
# image: 3/cup/right_obj_363.png - label: cup
# image: 3/cup/right_obj_358.png - label: cup
# image: 3/cup/right_obj_357.png - label: cup
# image: 3/cup/right_obj_355.png - label: cup
# image: 3/cup/right_obj_354.png - label: cup
# image: 3/cup/right_obj_353.png - label: cup
# image: 3/cup/right_obj_350.png - label: cup
# image: 3/cup/right_obj_352.png - label: cup
# image: 3/cup/right_obj_349.png - label: cup
# image: 3/cup/right_obj_348.png - label: cup
# image: 3/cup/right_obj_347.png - label: cup
# image: 3/cup/right_obj_341.png - label: cup
# image: 3/cup/right_obj_342.png - label: cup
# image: 3/cup/right_obj_344.png - label: cup
# image: 3/cup/right_obj_343.png - label: cup
# image: 3/cup/right_obj_340.png - label: cup
# image: 3/cup/right_obj_426.png - label: cup
# image: 3/cup/right_obj_431.png - label: cup
# image: 3/cup/right_obj_427.png - label: cup
# image: 3/cup/right_obj_428.png - label: cup
# image: 3/cup/right_obj_429.png - label: cup
# image: 3/cup/right_obj_424.png - label: cup
# image: 3/cup/right_obj_423.png - label: cup
# image: 3/cup/right_obj_421.png - label: cup
# image: 3/cup/right_obj_420.png - label: cup
# image: 3/cup/right_obj_419.png - label: cup
# image: 3/cup/right_obj_416.png - label: cup
# image: 3/cup/right_obj_418.png - label: cup
# image: 3/cup/right_obj_413.png - label: cup
# image: 3/cup/right_obj_409.png - label: cup
# image: 3/cup/right_obj_410.png - label: cup
# image: 3/cup/right_obj_414.png - label: cup
# image: 3/cup/right_obj_415.png - label: cup
# image: 3/cup/right_obj_408.png - label: cup
# image: 3/cup/right_obj_407.png - label: cup
# image: 3/cup/right_obj_406.png - label: cup
# image: 3/cup/right_obj_405.png - label: cup
# image: 3/cup/right_obj_399.png - label: cup
# image: 3/cup/right_obj_402.png - label: cup
# image: 3/cup/right_obj_401.png - label: cup
# image: 3/cup/right_obj_403.png - label: cup
# image: 3/cup/right_obj_397.png - label: cup
# image: 3/cup/right_obj_395.png - label: cup
# image: 3/cup/right_obj_396.png - label: cup
# image: 3/cup/right_obj_393.png - label: cup
# image: 3/cup/right_obj_394.png - label: cup
# image: 3/cup/right_obj_392.png - label: cup
# image: 3/cup/right_obj_388.png - label: cup
# image: 3/cup/right_obj_386.png - label: box
# image: 3/cup/right_obj_390.png - label: cup
# image: 3/cup/right_obj_387.png - label: cup
# image: 3/cup/right_obj_384.png - label: cup
# image: 3/cup/right_obj_382.png - label: cup
# image: 3/cup/right_obj_383.png - label: cup
# image: 3/cup/right_obj_380.png - label: cup
# image: 3/cup/right_obj_99.png - label: cup
# image: 3/cup/right_obj_98.png - label: cup
# image: 3/cup/right_obj_97.png - label: cup
# image: 3/cup/right_obj_96.png - label: cup
# image: 3/cup/right_obj_95.png - label: cup
# image: 3/cup/right_obj_93.png - label: cup
# image: 3/cup/right_obj_92.png - label: cup
# image: 3/cup/right_obj_91.png - label: book
# image: 3/cup/right_obj_90.png - label: cup
# image: 3/cup/right_obj_88.png - label: box
# image: 3/cup/right_obj_85.png - label: box
# image: 3/cup/right_obj_86.png - label: cup
# image: 3/cup/right_obj_87.png - label: cup
# image: 3/cup/right_obj_84.png - label: box
# image: 3/cup/right_obj_82.png - label: cup
# image: 3/cup/right_obj_437.png - label: cup
# image: 3/cup/right_obj_439.png - label: cup
# image: 3/cup/right_obj_83.png - label: cup
# image: 3/cup/right_obj_440.png - label: cup
# image: 3/cup/right_obj_438.png - label: cup
# image: 3/cup/right_obj_436.png - label: cup
# image: 3/cup/right_obj_435.png - label: cup
# image: 3/cup/right_obj_434.png - label: cup
# image: 3/cup/right_obj_432.png - label: cup
# image: 3/box/right_obj_100.png - label: box
# image: 3/box/right_obj_455.png - label: box
# image: 3/box/right_obj_444.png - label: box
# image: 3/box/right_obj_45.png - label: box
# image: 3/box/right_obj_422.png - label: box
# image: 3/box/right_obj_400.png - label: box
# image: 3/box/right_obj_433.png - label: box
# image: 3/box/right_obj_389.png - label: box
# image: 3/box/right_obj_378.png - label: box
# image: 3/box/right_obj_345.png - label: box
# image: 3/box/right_obj_367.png - label: box
# image: 3/box/right_obj_34.png - label: box
# image: 3/box/right_obj_334.png - label: box
# image: 3/box/right_obj_301.png - label: box
# image: 3/box/right_obj_290.png - label: box
# image: 3/box/right_obj_323.png - label: box
# image: 3/box/right_obj_312.png - label: box
# image: 3/box/right_obj_268.png - label: box
# image: 3/box/right_obj_257.png - label: box
# image: 3/box/right_obj_246.png - label: box
# image: 3/box/right_obj_243.png - label: box
# image: 3/box/right_obj_240.png - label: box
# image: 3/box/right_obj_23.png - label: cup
# image: 3/box/right_obj_232.png - label: box
# image: 3/box/right_obj_221.png - label: box
# image: 3/box/right_obj_210.png - label: box
# image: 3/box/right_obj_238.png - label: box
# image: 3/box/right_obj_199.png - label: box
# image: 3/box/right_obj_177.png - label: box
# image: 3/box/right_obj_166.png - label: cup
# image: 3/box/right_obj_155.png - label: box
# image: 3/box/right_obj_144.png - label: cup
# image: 3/box/right_obj_1357.png - label: box
# image: 3/box/right_obj_122.png - label: box
# image: 3/box/right_obj_12.png - label: box
# image: 3/box/right_obj_1346.png - label: box
# image: 3/box/right_obj_111.png - label: cup
# image: 3/box/right_obj_518.png - label: cup
# image: 3/box/right_obj_516.png - label: box
# image: 3/box/right_obj_515.png - label: box
# image: 3/box/right_obj_514.png - label: box
# image: 3/box/right_obj_512.png - label: box
# image: 3/box/right_obj_508.png - label: box
# image: 3/box/right_obj_513.png - label: box
# image: 3/box/right_obj_511.png - label: box
# image: 3/box/right_obj_507.png - label: box
# image: 3/box/right_obj_509.png - label: box
# image: 3/box/right_obj_506.png - label: box
# image: 3/box/right_obj_504.png - label: box
# image: 3/box/right_obj_503.png - label: box
# image: 3/box/right_obj_502.png - label: box
# image: 3/box/right_obj_499.png - label: box
# image: 3/box/right_obj_500.png - label: box
# image: 3/box/right_obj_497.png - label: box
# image: 3/box/right_obj_501.png - label: box
# image: 3/box/right_obj_495.png - label: box
# image: 3/box/right_obj_496.png - label: box
# image: 3/box/right_obj_494.png - label: box
# image: 3/box/right_obj_492.png - label: box
# image: 3/box/right_obj_491.png - label: box
# image: 3/box/right_obj_490.png - label: box
# image: 3/box/right_obj_471.png - label: box
# image: 3/box/right_obj_489.png - label: box
# image: 3/box/right_obj_485.png - label: box
# image: 3/box/right_obj_488.png - label: box
# image: 3/box/right_obj_479.png - label: box
# image: 3/box/right_obj_487.png - label: box
# image: 3/box/right_obj_470.png - label: box
# image: 3/box/right_obj_468.png - label: box
# image: 3/box/right_obj_466.png - label: box
# image: 3/box/right_obj_649.png - label: box
# image: 3/box/right_obj_648.png - label: cup
# image: 3/box/right_obj_646.png - label: book
# image: 3/box/right_obj_645.png - label: book
# image: 3/box/right_obj_644.png - label: book
# image: 3/box/right_obj_643.png - label: book
# image: 3/box/right_obj_560.png - label: box
# image: 3/box/right_obj_559.png - label: box
# image: 3/box/right_obj_557.png - label: box
# image: 3/box/right_obj_56.png - label: box
# image: 3/box/right_obj_556.png - label: box
# image: 3/box/right_obj_555.png - label: box
# image: 3/box/right_obj_554.png - label: box
# image: 3/box/right_obj_552.png - label: box
# image: 3/box/right_obj_550.png - label: box
# image: 3/box/right_obj_551.png - label: box
# image: 3/box/right_obj_545.png - label: box
# image: 3/box/right_obj_544.png - label: box
# image: 3/box/right_obj_547.png - label: box
# image: 3/box/right_obj_549.png - label: box
# image: 3/box/right_obj_543.png - label: box
# image: 3/box/right_obj_548.png - label: box
# image: 3/box/right_obj_542.png - label: cup
# image: 3/box/right_obj_540.png - label: box
# image: 3/box/right_obj_539.png - label: box
# image: 3/box/right_obj_538.png - label: box
# image: 3/box/right_obj_537.png - label: box
# image: 3/box/right_obj_536.png - label: box
# image: 3/box/right_obj_535.png - label: box
# image: 3/box/right_obj_532.png - label: box
# image: 3/box/right_obj_531.png - label: box
# image: 3/box/right_obj_533.png - label: box
# image: 3/box/right_obj_530.png - label: box
# image: 3/box/right_obj_528.png - label: box
# image: 3/box/right_obj_527.png - label: box
# image: 3/box/right_obj_526.png - label: box
# image: 3/box/right_obj_523.png - label: box
# image: 3/box/right_obj_525.png - label: box
# image: 3/box/right_obj_520.png - label: box
# image: 3/box/right_obj_521.png - label: box
# image: 3/box/right_obj_524.png - label: box
# image: 3/box/right_obj_519.png - label: box
# image: 3/box/right_obj_682.png - label: cup
# image: 3/box/right_obj_684.png - label: box
# image: 3/box/right_obj_689.png - label: box
# image: 3/box/right_obj_685.png - label: cup
# image: 3/box/right_obj_686.png - label: box
# image: 3/box/right_obj_687.png - label: book
# image: 3/box/right_obj_681.png - label: box
# image: 3/box/right_obj_680.png - label: cup
# image: 3/box/right_obj_679.png - label: box
# image: 3/box/right_obj_678.png - label: cup
# image: 3/box/right_obj_672.png - label: book
# image: 3/box/right_obj_675.png - label: box
# image: 3/box/right_obj_677.png - label: box
# image: 3/box/right_obj_673.png - label: box
# image: 3/box/right_obj_670.png - label: box
# image: 3/box/right_obj_674.png - label: box
# image: 3/box/right_obj_67.png - label: cup
# image: 3/box/right_obj_669.png - label: box
# image: 3/box/right_obj_668.png - label: box
# image: 3/box/right_obj_667.png - label: box
# image: 3/box/right_obj_666.png - label: box
# image: 3/box/right_obj_663.png - label: box
# image: 3/box/right_obj_665.png - label: box
# image: 3/box/right_obj_661.png - label: book
# image: 3/box/right_obj_662.png - label: box
# image: 3/box/right_obj_660.png - label: book
# image: 3/box/right_obj_658.png - label: book
# image: 3/box/right_obj_657.png - label: box
# image: 3/box/right_obj_656.png - label: box
# image: 3/box/right_obj_655.png - label: book
# image: 3/box/right_obj_651.png - label: book
# image: 3/box/right_obj_654.png - label: book
# image: 3/box/right_obj_650.png - label: book
# image: 3/box/right_obj_653.png - label: cup
# image: 3/box/right_obj_741.png - label: box
# image: 3/box/right_obj_738.png - label: box
# image: 3/box/right_obj_740.png - label: box
# image: 3/box/right_obj_734.png - label: book
# image: 3/box/right_obj_737.png - label: box
# image: 3/box/right_obj_732.png - label: box
# image: 3/box/right_obj_735.png - label: box
# image: 3/box/right_obj_731.png - label: book
# image: 3/box/right_obj_730.png - label: box
# image: 3/box/right_obj_729.png - label: book
# image: 3/box/right_obj_728.png - label: box
# image: 3/box/right_obj_718.png - label: box
# image: 3/box/right_obj_721.png - label: book
# image: 3/box/right_obj_719.png - label: book
# image: 3/box/right_obj_723.png - label: book
# image: 3/box/right_obj_722.png - label: book
# image: 3/box/right_obj_727.png - label: box
# image: 3/box/right_obj_724.png - label: book
# image: 3/box/right_obj_717.png - label: box
# image: 3/box/right_obj_716.png - label: box
# image: 3/box/right_obj_715.png - label: box
# image: 3/box/right_obj_711.png - label: box
# image: 3/box/right_obj_703.png - label: box
# image: 3/box/right_obj_713.png - label: box
# image: 3/box/right_obj_704.png - label: box
# image: 3/box/right_obj_710.png - label: box
# image: 3/box/right_obj_705.png - label: box
# image: 3/box/right_obj_709.png - label: box
# image: 3/box/right_obj_708.png - label: box
# image: 3/box/right_obj_706.png - label: box
# image: 3/box/right_obj_702.png - label: box
# image: 3/box/right_obj_699.png - label: box
# image: 3/box/right_obj_698.png - label: cup
# image: 3/box/right_obj_696.png - label: cup
# image: 3/box/right_obj_701.png - label: box
# image: 3/box/right_obj_694.png - label: box
# image: 3/box/right_obj_697.png - label: box
# image: 3/box/right_obj_693.png - label: box
# image: 3/box/right_obj_692.png - label: box
# image: 3/box/right_obj_690.png - label: box
# image: 3/box/right_obj_691.png - label: box
# image: 3/box/right_obj_767.png - label: box
# image: 3/box/right_obj_89.png - label: box
# image: 3/box/right_obj_78.png - label: box
# image: 3/box/right_obj_766.png - label: cup
# image: 3/box/right_obj_757.png - label: box
# image: 3/box/right_obj_759.png - label: cup
# image: 3/box/right_obj_764.png - label: box
# image: 3/box/right_obj_761.png - label: cup
# image: 3/box/right_obj_762.png - label: cup
# image: 3/box/right_obj_763.png - label: box
# image: 3/box/right_obj_765.png - label: box
# image: 3/box/right_obj_756.png - label: box
# image: 3/box/right_obj_755.png - label: box
# image: 3/box/right_obj_754.png - label: cup
# image: 3/box/right_obj_745.png - label: book
# image: 3/box/right_obj_744.png - label: box
# image: 3/box/right_obj_750.png - label: box
# image: 3/box/right_obj_753.png - label: box
# image: 3/box/right_obj_748.png - label: cup
# image: 3/box/right_obj_749.png - label: box
# image: 3/box/right_obj_751.png - label: box
# image: 3/box/right_obj_743.png - label: box
# image: 3/box/right_obj_742.png - label: box
# image: 3/book/right_obj_1052.png - label: box
# image: 3/book/right_obj_1054.png - label: book
# image: 3/book/right_obj_1049.png - label: book
# image: 3/book/right_obj_1048.png - label: book
# image: 3/book/right_obj_1053.png - label: book
# image: 3/book/right_obj_1050.png - label: box
# image: 3/book/right_obj_1047.png - label: book
# image: 3/book/right_obj_1046.png - label: book
# image: 3/book/right_obj_1045.png - label: book
# image: 3/book/right_obj_1043.png - label: box
# image: 3/book/right_obj_1037.png - label: cup
# image: 3/book/right_obj_1036.png - label: book
# image: 3/book/right_obj_1038.png - label: book
# image: 3/book/right_obj_1042.png - label: book
# image: 3/book/right_obj_1041.png - label: box
# image: 3/book/right_obj_1040.png - label: book
# image: 3/book/right_obj_1035.png - label: box
# image: 3/book/right_obj_1034.png - label: book
# image: 3/book/right_obj_1033.png - label: box
# image: 3/book/right_obj_1031.png - label: book
# image: 3/book/right_obj_1028.png - label: box
# image: 3/book/right_obj_1026.png - label: box
# image: 3/book/right_obj_1025.png - label: box
# image: 3/book/right_obj_1024.png - label: book
# image: 3/book/right_obj_1029.png - label: cup
# image: 3/book/right_obj_1030.png - label: book
# image: 3/book/right_obj_1023.png - label: box
# image: 3/book/right_obj_1022.png - label: box
# image: 3/book/right_obj_1021.png - label: cup
# image: 3/book/right_obj_1018.png - label: cup
# image: 3/book/right_obj_1055.png - label: box
# image: 3/book/right_obj_1091.png - label: book
# image: 3/book/right_obj_1083.png - label: box
# image: 3/book/right_obj_1086.png - label: box
# image: 3/book/right_obj_1088.png - label: book
# image: 3/book/right_obj_1085.png - label: book
# image: 3/book/right_obj_1089.png - label: book
# image: 3/book/right_obj_1090.png - label: book
# image: 3/book/right_obj_1084.png - label: book
# image: 3/book/right_obj_1081.png - label: book
# image: 3/book/right_obj_1082.png - label: book
# image: 3/book/right_obj_1079.png - label: book
# image: 3/book/right_obj_1073.png - label: book
# image: 3/book/right_obj_1076.png - label: book
# image: 3/book/right_obj_1077.png - label: book
# image: 3/book/right_obj_1072.png - label: cup
# image: 3/book/right_obj_1071.png - label: box
# image: 3/book/right_obj_1078.png - label: box
# image: 3/book/right_obj_1074.png - label: book
# image: 3/book/right_obj_1070.png - label: box
# image: 3/book/right_obj_1069.png - label: book
# image: 3/book/right_obj_1067.png - label: cup
# image: 3/book/right_obj_1060.png - label: box
# image: 3/book/right_obj_1062.png - label: book
# image: 3/book/right_obj_1061.png - label: box
# image: 3/book/right_obj_1065.png - label: book
# image: 3/book/right_obj_1066.png - label: book
# image: 3/book/right_obj_1059.png - label: box
# image: 3/book/right_obj_1064.png - label: book
# image: 3/book/right_obj_1058.png - label: book
# image: 3/book/right_obj_1057.png - label: book
# image: 3/book/right_obj_1140.png - label: book
# image: 3/book/right_obj_1139.png - label: book
# image: 3/book/right_obj_1133.png - label: book
# image: 3/book/right_obj_1138.png - label: book
# image: 3/book/right_obj_1135.png - label: book
# image: 3/book/right_obj_1134.png - label: book
# image: 3/book/right_obj_1132.png - label: book
# image: 3/book/right_obj_1131.png - label: book
# image: 3/book/right_obj_1137.png - label: book
# image: 3/book/right_obj_1128.png - label: book
# image: 3/book/right_obj_1130.png - label: book
# image: 3/book/right_obj_1122.png - label: book
# image: 3/book/right_obj_1127.png - label: book
# image: 3/book/right_obj_1121.png - label: book
# image: 3/book/right_obj_1123.png - label: book
# image: 3/book/right_obj_1126.png - label: book
# image: 3/book/right_obj_1125.png - label: book
# image: 3/book/right_obj_1120.png - label: book
# image: 3/book/right_obj_1118.png - label: book
# image: 3/book/right_obj_1119.png - label: book
# image: 3/book/right_obj_1116.png - label: book
# image: 3/book/right_obj_1107.png - label: cup
# image: 3/book/right_obj_1115.png - label: book
# image: 3/book/right_obj_1108.png - label: book
# image: 3/book/right_obj_1109.png - label: book
# image: 3/book/right_obj_1114.png - label: book
# image: 3/book/right_obj_1106.png - label: book
# image: 3/book/right_obj_1110.png - label: book
# image: 3/book/right_obj_1113.png - label: book
# image: 3/book/right_obj_1105.png - label: book
# image: 3/book/right_obj_1103.png - label: cup
# image: 3/book/right_obj_1102.png - label: book
# image: 3/book/right_obj_1100.png - label: book
# image: 3/book/right_obj_1098.png - label: book
# image: 3/book/right_obj_1101.png - label: book
# image: 3/book/right_obj_1097.png - label: book
# image: 3/book/right_obj_1094.png - label: book
# image: 3/book/right_obj_1096.png - label: book
# image: 3/book/right_obj_1093.png - label: book
# image: 3/book/right_obj_1095.png - label: book
# image: 3/book/right_obj_1279.png - label: box
# image: 3/book/right_obj_1277.png - label: book
# image: 3/book/right_obj_1271.png - label: book
# image: 3/book/right_obj_1270.png - label: box
# image: 3/book/right_obj_1278.png - label: book
# image: 3/book/right_obj_1276.png - label: book
# image: 3/book/right_obj_1272.png - label: box
# image: 3/book/right_obj_1273.png - label: box
# image: 3/book/right_obj_1274.png - label: book
# image: 3/book/right_obj_1268.png - label: box
# image: 3/book/right_obj_1266.png - label: book
# image: 3/book/right_obj_1260.png - label: book
# image: 3/book/right_obj_1259.png - label: box
# image: 3/book/right_obj_1261.png - label: cup
# image: 3/book/right_obj_1264.png - label: book
# image: 3/book/right_obj_1263.png - label: box
# image: 3/book/right_obj_1265.png - label: book
# image: 3/book/right_obj_1257.png - label: book
# image: 3/book/right_obj_1256.png - label: box
# image: 3/book/right_obj_1255.png - label: box
# image: 3/book/right_obj_1253.png - label: box
# image: 3/book/right_obj_1248.png - label: box
# image: 3/book/right_obj_1252.png - label: book
# image: 3/book/right_obj_1246.png - label: book
# image: 3/book/right_obj_1245.png - label: box
# image: 3/book/right_obj_1251.png - label: box
# image: 3/book/right_obj_1250.png - label: book
# image: 3/book/right_obj_1244.png - label: box
# image: 3/book/right_obj_1243.png - label: book
# image: 3/book/right_obj_1242.png - label: box
# image: 3/book/right_obj_1240.png - label: book
# image: 3/book/right_obj_1142.png - label: book
# image: 3/book/right_obj_1144.png - label: book
# image: 3/book/right_obj_1238.png - label: box
# image: 3/book/right_obj_1239.png - label: box
# image: 3/book/right_obj_1143.png - label: book
# image: 3/book/right_obj_1233.png - label: box
# image: 3/book/right_obj_1234.png - label: book
# image: 3/book/right_obj_1237.png - label: book
# image: 3/book/right_obj_1232.png - label: box
# image: 3/book/right_obj_1332.png - label: book
# image: 3/book/right_obj_1331.png - label: book
# image: 3/book/right_obj_1330.png - label: book
# image: 3/book/right_obj_1329.png - label: book
# image: 3/book/right_obj_1326.png - label: book
# image: 3/book/right_obj_1323.png - label: book
# image: 3/book/right_obj_1327.png - label: book
# image: 3/book/right_obj_1325.png - label: book
# image: 3/book/right_obj_1322.png - label: book
# image: 3/book/right_obj_1321.png - label: book
# image: 3/book/right_obj_1319.png - label: book
# image: 3/book/right_obj_1312.png - label: book
# image: 3/book/right_obj_1314.png - label: box
# image: 3/book/right_obj_1317.png - label: book
# image: 3/book/right_obj_1311.png - label: book
# image: 3/book/right_obj_1310.png - label: book
# image: 3/book/right_obj_1318.png - label: book
# image: 3/book/right_obj_1308.png - label: book
# image: 3/book/right_obj_1316.png - label: book
# image: 3/book/right_obj_1309.png - label: book
# image: 3/book/right_obj_1306.png - label: book
# image: 3/book/right_obj_1299.png - label: book
# image: 3/book/right_obj_1300.png - label: cup
# image: 3/book/right_obj_1303.png - label: book
# image: 3/book/right_obj_1298.png - label: book
# image: 3/book/right_obj_1304.png - label: book
# image: 3/book/right_obj_1305.png - label: book
# image: 3/book/right_obj_1296.png - label: book
# image: 3/book/right_obj_1295.png - label: book
# image: 3/book/right_obj_1297.png - label: book
# image: 3/book/right_obj_1293.png - label: book
# image: 3/book/right_obj_1289.png - label: book
# image: 3/book/right_obj_1292.png - label: book
# image: 3/book/right_obj_1285.png - label: book
# image: 3/book/right_obj_1287.png - label: box
# image: 3/book/right_obj_1290.png - label: box
# image: 3/book/right_obj_1284.png - label: box
# image: 3/book/right_obj_1282.png - label: book
# image: 3/book/right_obj_1286.png - label: book
# image: 3/book/right_obj_1283.png - label: book
# image: 3/book/right_obj_856.png - label: book
# image: 3/book/right_obj_859.png - label: book
# image: 3/book/right_obj_855.png - label: book
# image: 3/book/right_obj_854.png - label: book
# image: 3/book/right_obj_852.png - label: book
# image: 3/book/right_obj_858.png - label: book
# image: 3/book/right_obj_851.png - label: book
# image: 3/book/right_obj_850.png - label: book
# image: 3/book/right_obj_847.png - label: book
# image: 3/book/right_obj_849.png - label: book
# image: 3/book/right_obj_839.png - label: book
# image: 3/book/right_obj_845.png - label: book
# image: 3/book/right_obj_844.png - label: book
# image: 3/book/right_obj_843.png - label: book
# image: 3/book/right_obj_841.png - label: box
# image: 3/book/right_obj_842.png - label: book
# image: 3/book/right_obj_838.png - label: book
# image: 3/book/right_obj_837.png - label: book
# image: 3/book/right_obj_836.png - label: book
# image: 3/book/right_obj_833.png - label: book
# image: 3/book/right_obj_832.png - label: book
# image: 3/book/right_obj_830.png - label: cup
# image: 3/book/right_obj_1364.png - label: book
# image: 3/book/right_obj_1362.png - label: book
# image: 3/book/right_obj_1363.png - label: book
# image: 3/book/right_obj_831.png - label: cup
# image: 3/book/right_obj_829.png - label: book
# image: 3/book/right_obj_1359.png - label: book
# image: 3/book/right_obj_828.png - label: book
# image: 3/book/right_obj_1361.png - label: book
# image: 3/book/right_obj_1352.png - label: book
# image: 3/book/right_obj_1358.png - label: book
# image: 3/book/right_obj_1350.png - label: book
# image: 3/book/right_obj_1353.png - label: book
# image: 3/book/right_obj_1356.png - label: book
# image: 3/book/right_obj_1349.png - label: book
# image: 3/book/right_obj_1351.png - label: book
# image: 3/book/right_obj_1355.png - label: book
# image: 3/book/right_obj_1348.png - label: book
# image: 3/book/right_obj_1345.png - label: book
# image: 3/book/right_obj_1340.png - label: book
# image: 3/book/right_obj_1336.png - label: cup
# image: 3/book/right_obj_1337.png - label: book
# image: 3/book/right_obj_1343.png - label: book
# image: 3/book/right_obj_1344.png - label: book
# image: 3/book/right_obj_1338.png - label: book
# image: 3/book/right_obj_1339.png - label: book
# image: 3/book/right_obj_1334.png - label: book
# image: 3/book/right_obj_1342.png - label: book
# image: 3/book/right_obj_909.png - label: book
# image: 3/book/right_obj_901.png - label: book
# image: 3/book/right_obj_905.png - label: book
# image: 3/book/right_obj_908.png - label: book
# image: 3/book/right_obj_906.png - label: book
# image: 3/book/right_obj_903.png - label: book
# image: 3/book/right_obj_907.png - label: book
# image: 3/book/right_obj_900.png - label: book
# image: 3/book/right_obj_902.png - label: book
# image: 3/book/right_obj_898.png - label: book
# image: 3/book/right_obj_893.png - label: book
# image: 3/book/right_obj_896.png - label: book
# image: 3/book/right_obj_894.png - label: book
# image: 3/book/right_obj_890.png - label: book
# image: 3/book/right_obj_895.png - label: book
# image: 3/book/right_obj_891.png - label: book
# image: 3/book/right_obj_897.png - label: book
# image: 3/book/right_obj_889.png - label: book
# image: 3/book/right_obj_888.png - label: book
# image: 3/book/right_obj_886.png - label: book
# image: 3/book/right_obj_885.png - label: book
# image: 3/book/right_obj_884.png - label: book
# image: 3/book/right_obj_877.png - label: book
# image: 3/book/right_obj_882.png - label: book
# image: 3/book/right_obj_881.png - label: book
# image: 3/book/right_obj_883.png - label: book
# image: 3/book/right_obj_878.png - label: book
# image: 3/book/right_obj_875.png - label: book
# image: 3/book/right_obj_876.png - label: book
# image: 3/book/right_obj_873.png - label: book
# image: 3/book/right_obj_871.png - label: book
# image: 3/book/right_obj_865.png - label: book
# image: 3/book/right_obj_869.png - label: book
# image: 3/book/right_obj_864.png - label: book
# image: 3/book/right_obj_863.png - label: book
# image: 3/book/right_obj_867.png - label: book
# image: 3/book/right_obj_872.png - label: book
# image: 3/book/right_obj_870.png - label: book
# image: 3/book/right_obj_860.png - label: book
# image: 3/book/right_obj_862.png - label: book
# image: 3/book/right_obj_944.png - label: book
# image: 3/book/right_obj_939.png - label: book
# image: 3/book/right_obj_936.png - label: book
# image: 3/book/right_obj_943.png - label: book
# image: 3/book/right_obj_941.png - label: box
# image: 3/book/right_obj_945.png - label: book
# image: 3/book/right_obj_937.png - label: book
# image: 3/book/right_obj_942.png - label: box
# image: 3/book/right_obj_938.png - label: book
# image: 3/book/right_obj_934.png - label: book
# image: 3/book/right_obj_930.png - label: book
# image: 3/book/right_obj_929.png - label: book
# image: 3/book/right_obj_924.png - label: book
# image: 3/book/right_obj_931.png - label: book
# image: 3/book/right_obj_932.png - label: box
# image: 3/book/right_obj_933.png - label: book
# image: 3/book/right_obj_927.png - label: book
# image: 3/book/right_obj_926.png - label: box
# image: 3/book/right_obj_925.png - label: book
# image: 3/book/right_obj_922.png - label: book
# image: 3/book/right_obj_915.png - label: book
# image: 3/book/right_obj_921.png - label: box
# image: 3/book/right_obj_920.png - label: book
# image: 3/book/right_obj_914.png - label: book
# image: 3/book/right_obj_919.png - label: book
# image: 3/book/right_obj_917.png - label: book
# image: 3/book/right_obj_918.png - label: book
# image: 3/book/right_obj_913.png - label: book
# image: 3/book/right_obj_912.png - label: box
# image: 3/book/right_obj_910.png - label: book
# image: 3/book/right_obj_949.png - label: book
# image: 3/book/right_obj_948.png - label: book
# image: 3/book/right_obj_950.png - label: cup
# image: 3/book/right_obj_946.png - label: book
# Reuslts out of  724 test images - TRAIN 3 - (365, 250, 250)
# {'book': 240, 'box': 167, 'cup': 188}
# Accuracy: 0.822

# %% [markdown]
# ### More test

# %%
max = 0
max_c = -1
for i in range(1,50):
    # Train the Linear SVM
    #print("Train SVM")
    #svc = SVC()
    #clf = GridSearchCV(svc, param_grid)
    #clf = LinearSVC(tol=1e-10,max_iter=1e6)
    #clf = LinearSVC()
    c = i
    print("c: "+str(c))
    clf = SVC( C=c, kernel='rbf', gamma='scale', shrinking=True, tol=1e-6, cache_size=200, decision_function_shape='ovr')
    #clf = SVC( C=1000, kernel='linear', tol=1e-6, cache_size=200, decision_function_shape='ovr')
    clf.fit(im_features, np.array(image_classes))
    #sorted(clf.cv_results_.keys())
    # Save the SVM
    #print("Save SVM")
    #joblib.dump((clf, training_names, stdSlr, k, voc, im_features), "bof.pkl", compress=3)


    # Load the classifier, class names, scaler, number of clusters and vocabulary 
    #clf, classes_names, stdSlr, k, voc, train_features = joblib.load("bof.pkl")


    # Get the path of the testing image(s) and store them in a list
    image_paths = []
    #test_path = 'drive/MyDrive/Denmark/DTU/1 Year/II semester /PfAS/Final Project/Dataset/resized_data/test/'
    test_path = './Dataset/test_unoccluded/' 
    try:
        testing_names = os.listdir(test_path)
    except OSError:
        print("No such directory %s\nCheck if the file exists"%(test_path))
        exit()
    for testing_name in testing_names:
        dir = os.path.join(test_path, testing_name)
        class_path = imutils.imlist(dir)
        image_paths+=class_path


    # Perform the predictions
    #print(clf.predict(test_features))
    test_features = joblib.load("test_feat.pkl")
    predictions =  [classes_names[i] for i in clf.predict(test_features)]
    visulaize = True
    res = {"book": 0,"box": 0,"cup": 0}
    # Visualize the results, if "visualize" flag set to true by the user
    if visulaize:
        for image_path, prediction in zip(image_paths, predictions):
            #image = cv2.imread(image_path)
            #print("image: %s - label: %s"%(image_path[97:], prediction))
            if(image_path.find(prediction) > 0):
                res[prediction]+=1
            #cv2.namedWindow("Image", cv2.WINDOW_NORMAL)
            #pt = (0, 3 * image.shape[0] // 4)
            #cv2.putText(image, prediction, pt ,cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 2, [0, 255, 0], 2)
            #cv2.imshow("Image", image)
            #cv2.waitKey(50)
    print("Reuslts out of  %g test images - TRAIN 3 - (365, 250, 250)"%(len(predictions)))
    print(res)
    ris = [res[k] for k in res]
    acc = sum(ris)/len(predictions)
    print("Accuracy: %.3g"%(acc))
    if(acc > max):
        max = acc
        max_c = c
    #cv2.destroyAllWindows()

print("Max acc: %g at C:%d"%(max,max_c))
# Out:
# c: 1
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 76, 'box': 81, 'cup': 28}
# Accuracy: 0.663
# c: 2
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 76, 'box': 76, 'cup': 40}
# Accuracy: 0.688
# c: 3
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 76, 'box': 73, 'cup': 55}
# Accuracy: 0.731
# c: 4
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 76, 'box': 69, 'cup': 66}
# Accuracy: 0.756
# c: 5
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 76, 'box': 67, 'cup': 70}
# Accuracy: 0.763
# c: 6
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 73, 'box': 65, 'cup': 68}
# Accuracy: 0.738
# c: 7
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 72, 'box': 63, 'cup': 68}
# Accuracy: 0.728
# c: 8
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 73, 'box': 63, 'cup': 67}
# Accuracy: 0.728
# c: 9
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 73, 'box': 62, 'cup': 67}
# Accuracy: 0.724
# c: 10
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 72, 'box': 60, 'cup': 65}
# Accuracy: 0.706
# c: 11
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 72, 'box': 60, 'cup': 63}
# Accuracy: 0.699
# c: 12
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 71, 'box': 57, 'cup': 64}
# Accuracy: 0.688
# c: 13
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 72, 'box': 55, 'cup': 64}
# Accuracy: 0.685
# c: 14
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 73, 'box': 54, 'cup': 64}
# Accuracy: 0.685
# c: 15
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 72, 'box': 54, 'cup': 66}
# Accuracy: 0.688
# c: 16
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 72, 'box': 53, 'cup': 66}
# Accuracy: 0.685
# c: 17
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 73, 'box': 52, 'cup': 65}
# Accuracy: 0.681
# c: 18
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 73, 'box': 52, 'cup': 64}
# Accuracy: 0.677
# c: 19
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 73, 'box': 52, 'cup': 65}
# Accuracy: 0.681
# c: 20
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 73, 'box': 53, 'cup': 64}
# Accuracy: 0.681
# c: 21
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 73, 'box': 53, 'cup': 64}
# Accuracy: 0.681
# c: 22
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 73, 'box': 53, 'cup': 64}
# Accuracy: 0.681
# c: 23
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 51, 'cup': 64}
# Accuracy: 0.677
# c: 24
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 51, 'cup': 63}
# Accuracy: 0.674
# c: 25
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 51, 'cup': 63}
# Accuracy: 0.674
# c: 26
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 51, 'cup': 63}
# Accuracy: 0.674
# c: 27
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 52, 'cup': 62}
# Accuracy: 0.674
# c: 28
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 52, 'cup': 62}
# Accuracy: 0.674
# c: 29
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 52, 'cup': 63}
# Accuracy: 0.677
# c: 30
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 73, 'box': 50, 'cup': 63}
# Accuracy: 0.667
# c: 31
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 73, 'box': 49, 'cup': 63}
# Accuracy: 0.663
# c: 32
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 73, 'box': 49, 'cup': 63}
# Accuracy: 0.663
# c: 33
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 49, 'cup': 61}
# Accuracy: 0.659
# c: 34
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 49, 'cup': 62}
# Accuracy: 0.663
# c: 35
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 49, 'cup': 62}
# Accuracy: 0.663
# c: 36
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 49, 'cup': 63}
# Accuracy: 0.667
# c: 37
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 49, 'cup': 64}
# Accuracy: 0.67
# c: 38
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 49, 'cup': 64}
# Accuracy: 0.67
# c: 39
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 49, 'cup': 64}
# Accuracy: 0.67
# c: 40
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 50, 'cup': 64}
# Accuracy: 0.674
# c: 41
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 49, 'cup': 65}
# Accuracy: 0.674
# c: 42
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 49, 'cup': 65}
# Accuracy: 0.674
# c: 43
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 48, 'cup': 65}
# Accuracy: 0.67
# c: 44
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 73, 'box': 49, 'cup': 66}
# Accuracy: 0.674
# c: 45
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 73, 'box': 49, 'cup': 67}
# Accuracy: 0.677
# c: 46
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 49, 'cup': 67}
# Accuracy: 0.681
# c: 47
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 50, 'cup': 67}
# Accuracy: 0.685
# c: 48
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 50, 'cup': 67}
# Accuracy: 0.685
# c: 49
# Reuslts out of  279 test images - TRAIN 3 - (365, 250, 250)
# {'book': 74, 'box': 50, 'cup': 68}
# Accuracy: 0.688
# Max acc: 0.763441 at C:5

# %% [markdown]
# ### Single function

# %%
# variables needed: voc, k, class_names, clf 
def classifyBoW(image):
    # load parmeters (can be loaded only ones at the beginning of the code)
    #clf, classes_names, stdSlr, k, voc, train_features = joblib.load("bof.pkl")
    file=open('bof_p.pkl', 'rb')
    clf, classes_names, stdSlr, k, voc, train_features = pickle.load(file)

    # Create feature extraction and keypoint detector objects
    sift = cv2.xfeatures2d.SIFT_create(200)
    
    # List where all the descriptors are stored
    kpts, descriptors = sift.detectAndCompute(image,None)  
    
    test_features = np.zeros((1, k), "float32")
    
    words, distance = vq(descriptors,voc)
    for w in words:
        test_features[0][w] += 1

    # Perform Tf-Idf vectorization
    nbr_occurences = np.sum( (test_features > 0) * 1, axis = 0)
    idf = np.array(np.log((1.0+1) / (1.0*nbr_occurences + 1)), 'float32')

    # Scale the features
    test_features = stdSlr.transform(test_features)
    prediction =  classes_names[clf.predict(test_features)[0]]
    return prediction

# %%
image_paths = []
testing_names = os.listdir(test_path)
#for testing_name in testing_names:
dir = os.path.join(test_path, "cup")
class_path = imutils.imlist(dir)
image_paths=class_path
print("Accuracy non occluded dataset")
cups = 0;
total_cups = len(image_paths)
for im_path in image_paths:
    im = cv2.imread(im_path)
    p = classifyBoW(im)
    if(p=='cup'):
        cups+=1
    #print("prediction: %s"%(p))
print("Accuracy cups: %g"%(cups/total_cups))


dir = os.path.join(test_path, "book")
class_path = imutils.imlist(dir)
image_paths=class_path
#print(image_paths)

books = 0;
total_books = len(image_paths)
for im_path in image_paths:
    im = cv2.imread(im_path)
    p = classifyBoW(im)
    if(p=='book'):
        books+=1
    #print("prediction: %s"%(p))
print("Accuracy books: %g"%(books/total_books))


dir = os.path.join(test_path, "box")
class_path = imutils.imlist(dir)
image_paths=class_path
#print(image_paths)

boxes = 0;
total_boxes = len(image_paths)
for im_path in image_paths:
    im = cv2.imread(im_path)
    p = classifyBoW(im)
    if(p=='box'):
        boxes+=1
    #print("prediction: %s"%(p))
print("Accuracy boxes: %g"%(boxes/total_boxes))
# Out:
# Accuracy non occluded dataset
# Accuracy cups: 0.913462
# Accuracy books: 0.803279
# Accuracy boxes: 0.953488
